# %%
import git
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Repository details
repo_url = "https://github.com/nf-core/rnaseq.git"
repo_path = "rnaseq_repo"
GITHUB_TOKEN = "{{GITHUB TOKEN}}"  # Replace with your token
repo_owner = "nf-core"
repo_name = "rnaseq"
headers = {"Authorization": f"token {GITHUB_TOKEN}"}

# Clone if not exists
if not os.path.exists(repo_path):
    git.Repo.clone_from(repo_url, repo_path)
    print(f"Repository cloned: {repo_url}")
else:
    print(f"Repository already exists at: {repo_path}")

repo = git.Repo(repo_path)

# Extract commit logs
def get_commit_logs(repo):
    commit_data = []
    for commit in repo.iter_commits():
        commit_data.append({
            "Commit Hash": commit.hexsha,
            "Author": commit.author.name,
            "Date": commit.authored_datetime,
            "Message": commit.message
        })
    df_commits = pd.DataFrame(commit_data)
    display(df_commits)
    return df_commits  

df_commits = get_commit_logs(repo)  # Store returned DataFrame

# Extract file modifications
def get_file_modifications(repo):
    file_modifications = {}
    for commit in repo.iter_commits():
        for file in commit.stats.files:
            file_modifications[file] = file_modifications.get(file, 0) + 1
    df_files = pd.DataFrame(file_modifications.items(), columns=["File", "Changes"])
    df_files = df_files.sort_values(by="Changes", ascending=False)
    display(df_files)

get_file_modifications(repo)

# Extract reflog
def get_reflog(repo):
    reflog_entries = []
    for ref in repo.refs:
        for entry in ref.log():
            reflog_entries.append({
                "Old SHA": entry.oldhexsha,
                "New SHA": entry.newhexsha,
                "Action": entry.message,
                "Timestamp": entry.time[0]
            })
    df_reflog = pd.DataFrame(reflog_entries)
    display(df_reflog)

get_reflog(repo)

# Extract branch history
def get_branches(repo):
    branches = [str(branch) for branch in repo.branches]
    df_branches = pd.DataFrame(branches, columns=["Branch Name"])
    display(df_branches)

get_branches(repo)

# Fetch GitHub events
def fetch_github_events():
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/events"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        df_events = pd.DataFrame(response.json())
        display(df_events)
    else:
        print("Failed to fetch events", response.status_code)

fetch_github_events()

# Fetch issues
def fetch_github_issues():
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/issues"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        df_issues = pd.DataFrame(response.json())
        display(df_issues)
    else:
        print("Failed to fetch issues", response.status_code)

fetch_github_issues()

# Fetch pull requests
def fetch_github_prs():
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/pulls"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        df_prs = pd.DataFrame(response.json())
        display(df_prs)
    else:
        print("Failed to fetch pull requests", response.status_code)

fetch_github_prs()

# Fetch CI/CD Workflow runs
def fetch_github_actions():
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/actions/runs"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        df_workflows = pd.DataFrame(response.json()["workflow_runs"])
        display(df_workflows)
    else:
        print("Failed to fetch workflow logs", response.status_code)

fetch_github_actions()
# Out:
# Repository already exists at: rnaseq_repo
#                                    Commit Hash            Author  \
# 0     b96a75361a4f1d49aa969a2b1c68e3e607de06e8  Jonathan Manning
# 1     324dcdf877bca4a28934fd244c1565606eecd14c  Jonathan Manning
# 2     eb7d7640aa066189b4d98565cf37657fdb55d377  Jonathan Manning
# 3     1b593f7ae043f989c1e36dbfdd6109bae4081eaf  Jonathan Manning
# 4     aa1ac449283270bfed5c63e2510669c5f4b17b05  Jonathan Manning
# ...                                        ...               ...
# 5801  ab2aa45a263b388795907070c35af163a9bcca7e        Phil Ewels
# 5802  6d3100a94f90ca8b9e4276d5abe0deea18743d8e        Phil Ewels
# 5803  d6f7bfd522d82c77e6cb5d9c7982bc5bd6f9b1aa        Phil Ewels
# 5804  dc55ead5df34c0cbfdb65cbfcc2a4f4e90088351        Phil Ewels
# 5805  5b559dd51d817bc5b6f51d4f61952d1178dfb864        Phil Ewels
#
#                            Date  \
# 0     2024-12-20 16:49:29+00:00
# 1     2024-12-20 16:15:06+00:00
# 2     2024-12-20 15:54:19+00:00
# 3     2024-12-20 11:38:03+00:00
# 4     2024-12-20 11:23:37+00:00
# ...                         ...
# 5801  2016-03-01 17:10:49+01:00
# 5802  2016-03-01 17:07:17+01:00
# 5803  2016-03-01 17:04:46+01:00
# 5804  2016-03-01 16:39:36+01:00
# 5805  2016-03-01 15:40:50+01:00
#
#                                                 Message
# 0     Merge pull request #1476 from nf-core/dev\n\nD...
# 1     Merge pull request #1479 from nf-core/add_miss...
# 2                                   Update CHANGELOG.md
# 3     Merge pull request #1477 from nf-core/update_f...
# 4       Merge branch 'master' into update_from_master\n
# ...                                                 ...
# 5801                    further antimetagrobolization\n
# 5802                       Added example config file.\n
# 5803                            antimetagrobolization\n
# 5804                       Added start of rseqc step.\n
# 5805                                     First commit\n
#
# [5806 rows x 4 columns]
#                                             File  Changes
# 1                                   CHANGELOG.md     1391
# 146                                      main.nf     1298
# 55                               nextflow.config      724
# 8                                  docs/usage.md      545
# 136                                    README.md      481
# ...                                          ...      ...
# 1350  modules/local/process/parallelfastqdump.nf        2
# 1309                     modules/local/gunzip.nf        2
# 1308                      modules/local/untar.nf        2
# 1300                 schema_public_data_ids.json        2
# 794             tests/skip_trimming/main.nf.test        2
#
# [1589 rows x 2 columns]
#                                     Old SHA  \
# 0  0000000000000000000000000000000000000000
# 1  0000000000000000000000000000000000000000
#
#                                     New SHA  \
# 0  b96a75361a4f1d49aa969a2b1c68e3e607de06e8
# 1  b96a75361a4f1d49aa969a2b1c68e3e607de06e8
#
#                                               Action   Timestamp
# 0  clone: from https://github.com/nf-core/rnaseq.git  1738230824
# 1  clone: from https://github.com/nf-core/rnaseq.git  1738230824
#   Branch Name
# 0      master
#              id                           type  \
# 0   46304291272                     WatchEvent
# 1   46259137040                     WatchEvent
# 2   46253225321                     WatchEvent
# 3   46219575882                      ForkEvent
# 4   46164229786              IssueCommentEvent
# 5   46153628440              IssueCommentEvent
# 6   46146741193                     WatchEvent
# 7   46118245263                    IssuesEvent
# 8   46117941843                     WatchEvent
# 9   46073778160                      ForkEvent
# 10  46071377088                     WatchEvent
# 11  46070515542                      PushEvent
# 12  46067071453                      PushEvent
# 13  46067049060  PullRequestReviewCommentEvent
# 14  46067049074  PullRequestReviewCommentEvent
# 15  46067048963         PullRequestReviewEvent
# 16  46066663394  PullRequestReviewCommentEvent
# 17  46066663311         PullRequestReviewEvent
# 18  46066489443                      PushEvent
# 19  46066402796                      PushEvent
# 20  46065623006                      PushEvent
# 21  46065608487                      PushEvent
# 22  46060741300                    CreateEvent
# 23  46059556179                    DeleteEvent
# 24  46059555040                      PushEvent
# 25  46059554590               PullRequestEvent
# 26  46048124613         PullRequestReviewEvent
# 27  46039008225         PullRequestReviewEvent
# 28  46038998569  PullRequestReviewCommentEvent
# 29  46038998472         PullRequestReviewEvent
#
#                                                 actor  \
# 0   {'id': 76952241, 'login': 'flipojus', 'display...
# 1   {'id': 6922120, 'login': 'walaj', 'display_log...
# 2   {'id': 90332738, 'login': 'hutuliangmu', 'disp...
# 3   {'id': 194942988, 'login': 'henry-dai-61', 'di...
# 4   {'id': 114392778, 'login': 'b-lac', 'display_l...
# 5   {'id': 37644569, 'login': 'IrinaVKuznetsova', ...
# 6   {'id': 91340003, 'login': 'IbrahimBioComp', 'd...
# 7   {'id': 53092537, 'login': 'audrey-bollas', 'di...
# 8   {'id': 66436798, 'login': 'thscandolara', 'dis...
# 9   {'id': 35698247, 'login': 'gurpreet-bioinfo', ...
# 10  {'id': 113202485, 'login': 'WesFM', 'display_l...
# 11  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 12  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 13  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 14  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 15  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 16  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 17  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 18  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 19  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 20  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 21  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 22  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 23  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 24  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 25  {'id': 5775915, 'login': 'pinin4fjords', 'disp...
# 26  {'id': 1834905, 'login': 'charles-plessy', 'di...
# 27  {'id': 1019628, 'login': 'maxulysse', 'display...
# 28  {'id': 1019628, 'login': 'maxulysse', 'display...
# 29  {'id': 1019628, 'login': 'maxulysse', 'display...
#
#                                                  repo  \
# 0   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 1   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 2   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 3   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 4   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 5   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 6   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 7   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 8   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 9   {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 10  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 11  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 12  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 13  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 14  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 15  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 16  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 17  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 18  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 19  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 20  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 21  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 22  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 23  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 24  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 25  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 26  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 27  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 28  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
# 29  {'id': 127293091, 'name': 'nf-core/rnaseq', 'u...
#
#                                               payload  public  \
# 0                               {'action': 'started'}    True
# 1                               {'action': 'started'}    True
# 2                               {'action': 'started'}    True
# 3   {'forkee': {'id': 927212294, 'node_id': 'R_kgD...    True
# 4   {'action': 'created', 'issue': {'url': 'https:...    True
# 5   {'action': 'created', 'issue': {'url': 'https:...    True
# 6                               {'action': 'started'}    True
# 7   {'action': 'opened', 'issue': {'url': 'https:/...    True
# 8                               {'action': 'started'}    True
# 9   {'forkee': {'id': 924756281, 'node_id': 'R_kgD...    True
# 10                              {'action': 'started'}    True
# 11  {'repository_id': 127293091, 'push_id': 223949...    True
# 12  {'repository_id': 127293091, 'push_id': 223932...    True
# 13  {'action': 'created', 'comment': {'url': 'http...    True
# 14  {'action': 'created', 'comment': {'url': 'http...    True
# 15  {'action': 'created', 'review': {'id': 2583821...    True
# 16  {'action': 'created', 'comment': {'url': 'http...    True
# 17  {'action': 'created', 'review': {'id': 2583795...    True
# 18  {'repository_id': 127293091, 'push_id': 223929...    True
# 19  {'repository_id': 127293091, 'push_id': 223929...    True
# 20  {'repository_id': 127293091, 'push_id': 223924...    True
# 21  {'repository_id': 127293091, 'push_id': 223924...    True
# 22  {'ref': '3.14', 'ref_type': 'branch', 'master_...    True
# 23  {'ref': 'bump_multiqc', 'ref_type': 'branch', ...    True
# 24  {'repository_id': 127293091, 'push_id': 223895...    True
# 25  {'action': 'closed', 'number': 1499, 'pull_req...    True
# 26  {'action': 'created', 'review': {'id': 2582595...    True
# 27  {'action': 'created', 'review': {'id': 2581826...    True
# 28  {'action': 'created', 'comment': {'url': 'http...    True
# 29  {'action': 'created', 'review': {'id': 2581826...    True
#
#               created_at                                                org
# 0   2025-02-06T15:46:16Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 1   2025-02-05T14:32:25Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 2   2025-02-05T12:01:16Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 3   2025-02-04T15:37:25Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 4   2025-02-03T09:54:34Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 5   2025-02-03T02:19:30Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 6   2025-02-02T15:57:34Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 7   2025-01-31T19:20:10Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 8   2025-01-31T19:08:26Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 9   2025-01-30T15:47:39Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 10  2025-01-30T14:50:49Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 11  2025-01-30T14:21:55Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 12  2025-01-30T12:52:31Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 13  2025-01-30T12:51:12Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 14  2025-01-30T12:51:23Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 15  2025-01-30T12:51:54Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 16  2025-01-30T12:41:10Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 17  2025-01-30T12:41:11Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 18  2025-01-30T12:36:25Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 19  2025-01-30T12:34:02Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 20  2025-01-30T12:12:29Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 21  2025-01-30T12:12:03Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 22  2025-01-30T09:52:06Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 23  2025-01-30T09:18:17Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 24  2025-01-30T09:18:15Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 25  2025-01-30T09:18:14Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 26  2025-01-29T23:29:26Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 27  2025-01-29T18:00:10Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 28  2025-01-29T17:59:51Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
# 29  2025-01-29T17:59:52Z  {'id': 35520196, 'login': 'nf-core', 'gravatar...
#                                                   url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/is...
# 1   https://api.github.com/repos/nf-core/rnaseq/is...
# 2   https://api.github.com/repos/nf-core/rnaseq/is...
# 3   https://api.github.com/repos/nf-core/rnaseq/is...
# 4   https://api.github.com/repos/nf-core/rnaseq/is...
# 5   https://api.github.com/repos/nf-core/rnaseq/is...
# 6   https://api.github.com/repos/nf-core/rnaseq/is...
# 7   https://api.github.com/repos/nf-core/rnaseq/is...
# 8   https://api.github.com/repos/nf-core/rnaseq/is...
# 9   https://api.github.com/repos/nf-core/rnaseq/is...
# 10  https://api.github.com/repos/nf-core/rnaseq/is...
# 11  https://api.github.com/repos/nf-core/rnaseq/is...
# 12  https://api.github.com/repos/nf-core/rnaseq/is...
# 13  https://api.github.com/repos/nf-core/rnaseq/is...
# 14  https://api.github.com/repos/nf-core/rnaseq/is...
# 15  https://api.github.com/repos/nf-core/rnaseq/is...
# 16  https://api.github.com/repos/nf-core/rnaseq/is...
# 17  https://api.github.com/repos/nf-core/rnaseq/is...
# 18  https://api.github.com/repos/nf-core/rnaseq/is...
# 19  https://api.github.com/repos/nf-core/rnaseq/is...
# 20  https://api.github.com/repos/nf-core/rnaseq/is...
# 21  https://api.github.com/repos/nf-core/rnaseq/is...
# 22  https://api.github.com/repos/nf-core/rnaseq/is...
# 23  https://api.github.com/repos/nf-core/rnaseq/is...
# 24  https://api.github.com/repos/nf-core/rnaseq/is...
# 25  https://api.github.com/repos/nf-core/rnaseq/is...
# 26  https://api.github.com/repos/nf-core/rnaseq/is...
# 27  https://api.github.com/repos/nf-core/rnaseq/is...
# 28  https://api.github.com/repos/nf-core/rnaseq/is...
# 29  https://api.github.com/repos/nf-core/rnaseq/is...
#
#                                  repository_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq
# 1   https://api.github.com/repos/nf-core/rnaseq
# 2   https://api.github.com/repos/nf-core/rnaseq
# 3   https://api.github.com/repos/nf-core/rnaseq
# 4   https://api.github.com/repos/nf-core/rnaseq
# 5   https://api.github.com/repos/nf-core/rnaseq
# 6   https://api.github.com/repos/nf-core/rnaseq
# 7   https://api.github.com/repos/nf-core/rnaseq
# 8   https://api.github.com/repos/nf-core/rnaseq
# 9   https://api.github.com/repos/nf-core/rnaseq
# 10  https://api.github.com/repos/nf-core/rnaseq
# 11  https://api.github.com/repos/nf-core/rnaseq
# 12  https://api.github.com/repos/nf-core/rnaseq
# 13  https://api.github.com/repos/nf-core/rnaseq
# 14  https://api.github.com/repos/nf-core/rnaseq
# 15  https://api.github.com/repos/nf-core/rnaseq
# 16  https://api.github.com/repos/nf-core/rnaseq
# 17  https://api.github.com/repos/nf-core/rnaseq
# 18  https://api.github.com/repos/nf-core/rnaseq
# 19  https://api.github.com/repos/nf-core/rnaseq
# 20  https://api.github.com/repos/nf-core/rnaseq
# 21  https://api.github.com/repos/nf-core/rnaseq
# 22  https://api.github.com/repos/nf-core/rnaseq
# 23  https://api.github.com/repos/nf-core/rnaseq
# 24  https://api.github.com/repos/nf-core/rnaseq
# 25  https://api.github.com/repos/nf-core/rnaseq
# 26  https://api.github.com/repos/nf-core/rnaseq
# 27  https://api.github.com/repos/nf-core/rnaseq
# 28  https://api.github.com/repos/nf-core/rnaseq
# 29  https://api.github.com/repos/nf-core/rnaseq
#
#                                            labels_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/is...
# 1   https://api.github.com/repos/nf-core/rnaseq/is...
# 2   https://api.github.com/repos/nf-core/rnaseq/is...
# 3   https://api.github.com/repos/nf-core/rnaseq/is...
# 4   https://api.github.com/repos/nf-core/rnaseq/is...
# 5   https://api.github.com/repos/nf-core/rnaseq/is...
# 6   https://api.github.com/repos/nf-core/rnaseq/is...
# 7   https://api.github.com/repos/nf-core/rnaseq/is...
# 8   https://api.github.com/repos/nf-core/rnaseq/is...
# 24    https://github.com/nf-core/rnaseq/pull/1421  2597296424
# 25  https://github.com/nf-core/rnaseq/issues/1420  2595690920
# 26  https://github.com/nf-core/rnaseq/issues/1419  2594651290
# 27  https://github.com/nf-core/rnaseq/issues/1404  2578188552
# 28    https://github.com/nf-core/rnaseq/pull/1397  2561971880
# 29  https://github.com/nf-core/rnaseq/issues/1373  2506362354
#
#                 node_id  number  \
# 0    I_kwDOB5ZWo86o6deu    1502
# 1    I_kwDOB5ZWo86oVjrj    1501
# 2    I_kwDOB5ZWo86oTF5B    1500
# 3    I_kwDOB5ZWo86n8vs4    1498
# 4    I_kwDOB5ZWo86n6RCW    1497
# 5    I_kwDOB5ZWo86nTqi2    1494
# 6    I_kwDOB5ZWo86nLgUy    1491
# 7    I_kwDOB5ZWo86m-iRp    1489
# 8    I_kwDOB5ZWo86miFD0    1487
# 9    I_kwDOB5ZWo86lcbef    1483
# 10   I_kwDOB5ZWo86jzAGM    1472
# 11   I_kwDOB5ZWo86itVgv    1465
# 12   I_kwDOB5ZWo86goC8q    1457
# 13   I_kwDOB5ZWo86fnhvs    1455
# 14   I_kwDOB5ZWo86eLLG_    1450
# 15   I_kwDOB5ZWo86c6Ead    1449
# 16   I_kwDOB5ZWo86cNuNF    1445
# 17   I_kwDOB5ZWo86cKcuS    1444
# 18  PR_kwDOB5ZWo85_r0x5    1439
# 19  PR_kwDOB5ZWo85_qRVz    1438
# 20   I_kwDOB5ZWo86bdBPg    1431
# 21   I_kwDOB5ZWo86bc_as    1430
# 22   I_kwDOB5ZWo86bc-Vi    1429
# 23   I_kwDOB5ZWo86bc9k9    1428
# 24  PR_kwDOB5ZWo85_F82c    1421
# 25   I_kwDOB5ZWo86atxmo    1420
# 26   I_kwDOB5ZWo86apzya    1419
# 27   I_kwDOB5ZWo86ZrAkI    1404
# 28  PR_kwDOB5ZWo859ZCZy    1397
# 29   I_kwDOB5ZWo86VZA3y    1373
#
#                                                 title  ...  \
# 0                         issue while running nf core  ...
# 1   SortMeRNA stats in MultiQC report are reported...  ...
# 2                  salmon seems to remove transcripts  ...
# 3                     Execution time of module tin.py  ...
# 4          Arm profile platform should be linux/arm64  ...
# 5   Indexing only run does not produce all indexes...  ...
# 6   File "salmon.merged.gene_counts.tsv" Contains ...  ...
# 7   `FATAL: While making image from oci registry: ...  ...
# 8    No isoform-level quants from Star_Salmon Output.  ...
# 9   Error for single reads during FASTQ linting pr...  ...
# 10  working with gene panels or single genes (e.g....  ...
# 11                  Unify SummarizedExperiment output  ...
# 12  ERROR      Not able to pull image of ('biocont...  ...
# 13  singularity.registry ignored when pulling nf-c...  ...
# 14  Warn user if both `transcript_fasta` and `addi...  ...
# 15                           Sample name changed 3.16  ...
# 16  Error in findColumnWithAllEntries(ids, metadat...  ...
# 17  root filesystem extraction failed: extract com...  ...
# 18                      Try matthias' fix to download  ...
# 19                        implement sharding of tests  ...
# 20       Remove need for use of Seqera conda channels  ...
# 21                         Add ARM support for hisat2  ...
# 22                        Add ARM support for Bracken  ...
# 23                        Add ARM support for kraken2  ...
# 24                         allow integer sample names  ...
# 25                                   strandness error  ...
# 26           3.16.x does not allow numeric sample ids  ...
# 27  Restore the set -C when the concerned modules ...  ...
# 28                        Update nextflow_schema.json  ...
# 29  Option to keep chimeric reads after UMI dedupl...  ...
#
#                                    sub_issues_summary active_lock_reason  \
# 0   {'total': 0, 'completed': 0, 'percent_complete...               None
# 1   {'total': 0, 'completed': 0, 'percent_complete...               None
# 2   {'total': 0, 'completed': 0, 'percent_complete...               None
# 3   {'total': 0, 'completed': 0, 'percent_complete...               None
# 4   {'total': 0, 'completed': 0, 'percent_complete...               None
# 5   {'total': 0, 'completed': 0, 'percent_complete...               None
# 6   {'total': 0, 'completed': 0, 'percent_complete...               None
# 7   {'total': 0, 'completed': 0, 'percent_complete...               None
# 8   {'total': 0, 'completed': 0, 'percent_complete...               None
# 9   {'total': 0, 'completed': 0, 'percent_complete...               None
# 10  {'total': 0, 'completed': 0, 'percent_complete...               None
# 11  {'total': 0, 'completed': 0, 'percent_complete...               None
# 12  {'total': 0, 'completed': 0, 'percent_complete...               None
# 13  {'total': 0, 'completed': 0, 'percent_complete...               None
# 14  {'total': 0, 'completed': 0, 'percent_complete...               None
# 15  {'total': 0, 'completed': 0, 'percent_complete...               None
# 16  {'total': 0, 'completed': 0, 'percent_complete...               None
# 17  {'total': 0, 'completed': 0, 'percent_complete...               None
# 18  {'total': 0, 'completed': 0, 'percent_complete...               None
# 19  {'total': 0, 'completed': 0, 'percent_complete...               None
# 20  {'total': 0, 'completed': 0, 'percent_complete...               None
# 21  {'total': 0, 'completed': 0, 'percent_complete...               None
# 22  {'total': 0, 'completed': 0, 'percent_complete...               None
# 23  {'total': 0, 'completed': 0, 'percent_complete...               None
# 24  {'total': 0, 'completed': 0, 'percent_complete...               None
# 25  {'total': 0, 'completed': 0, 'percent_complete...               None
# 26  {'total': 0, 'completed': 0, 'percent_complete...               None
# 27  {'total': 0, 'completed': 0, 'percent_complete...               None
# 28  {'total': 0, 'completed': 0, 'percent_complete...               None
# 29  {'total': 0, 'completed': 0, 'percent_complete...               None
#
#                                                  body  \
# 0   ### Description of the bug\n\n\nERROR ~ Error ...
# 1   ### Description of the bug\n\nThe final MultiQ...
# 2   Hi,\n\nI'm running a pipeline for unique mappi...
# 3   Dear Team,\n\nI am using rna seq pipeline vers...
# 4   ### Description of the bug\n\nIn #1425 config ...
# 5   ### Description of the bug\n\nThe [docs recomm...
# 6   ### Description of the bug\n\nDear nf-core tea...
# 7   ### Description of the bug\n\nHello, \n\nAfter...
# 8   Hi All,\nI am new to working with nextflow's r...
# 9   ### Description of the bug\n\nHi,\n\nI've trie...
# 10  Are there any recommendations for working with...
# 11  ### Description of feature\n\nCurrently, the p...
# 12  ### Description of the bug\n\nHi, when downloa...
# 13  ### Description of the bug\n\nFrom terminal ou...
# 14  ### Description of feature\n\nPipeline fails i...
# 15  ### Description of the bug\n\nHi, I notice tha...
# 16  ### Description of the bug\n\nHey, on the curr...
# 17  ### Description of the bug\n\nI don’t have roo...
# 18  <!--\r\n# nf-core/rnaseq pull request\r\n\r\nM...
# 19  Adapted from https://github.com/nf-core/sarek/...
# 20  ### Description of feature\n\nSeqera generated...
# 21  ### Description of feature\n\nhisat2 is curren...
# 22  ### Description of feature\n\nBracken is curre...
# 23  ### Description of feature\n\nKraken2 is curre...
# 24  int was not allowed as sample name anymore (si...
# 25  ### Description of the bug\n\nHi there,\nCould...
# 26  ### Description of the bug\n\nHello,\na sample...
# 27                TODO: restore the -C when the co...
# 28  <!--\r\n# nf-core/rnaseq pull request\r\n\r\nM...
# 29  ### Description of feature\n\nFollowing up on ...
#
#                                             closed_by  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  {'login': 'idot', 'id': 104748, 'node_id': 'MD...
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/nf-core/...
# 1   {'url': 'https://api.github.com/repos/nf-core/...
# 2   {'url': 'https://api.github.com/repos/nf-core/...
# 3   {'url': 'https://api.github.com/repos/nf-core/...
# 4   {'url': 'https://api.github.com/repos/nf-core/...
# 5   {'url': 'https://api.github.com/repos/nf-core/...
# 6   {'url': 'https://api.github.com/repos/nf-core/...
# 7   {'url': 'https://api.github.com/repos/nf-core/...
# 8   {'url': 'https://api.github.com/repos/nf-core/...
# 9   {'url': 'https://api.github.com/repos/nf-core/...
# 10  {'url': 'https://api.github.com/repos/nf-core/...
# 11  {'url': 'https://api.github.com/repos/nf-core/...
# 12  {'url': 'https://api.github.com/repos/nf-core/...
# 13  {'url': 'https://api.github.com/repos/nf-core/...
# 14  {'url': 'https://api.github.com/repos/nf-core/...
# 15  {'url': 'https://api.github.com/repos/nf-core/...
# 16  {'url': 'https://api.github.com/repos/nf-core/...
# 17  {'url': 'https://api.github.com/repos/nf-core/...
# 18  {'url': 'https://api.github.com/repos/nf-core/...
# 19  {'url': 'https://api.github.com/repos/nf-core/...
# 20  {'url': 'https://api.github.com/repos/nf-core/...
# 21  {'url': 'https://api.github.com/repos/nf-core/...
# 22  {'url': 'https://api.github.com/repos/nf-core/...
# 23  {'url': 'https://api.github.com/repos/nf-core/...
# 24  {'url': 'https://api.github.com/repos/nf-core/...
# 25  {'url': 'https://api.github.com/repos/nf-core/...
# 26  {'url': 'https://api.github.com/repos/nf-core/...
# 27  {'url': 'https://api.github.com/repos/nf-core/...
# 28  {'url': 'https://api.github.com/repos/nf-core/...
# 29  {'url': 'https://api.github.com/repos/nf-core/...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/is...
# 1   https://api.github.com/repos/nf-core/rnaseq/is...
# 2   https://api.github.com/repos/nf-core/rnaseq/is...
# 3   https://api.github.com/repos/nf-core/rnaseq/is...
# 4   https://api.github.com/repos/nf-core/rnaseq/is...
# 5   https://api.github.com/repos/nf-core/rnaseq/is...
# 6   https://api.github.com/repos/nf-core/rnaseq/is...
# 7   https://api.github.com/repos/nf-core/rnaseq/is...
# 8   https://api.github.com/repos/nf-core/rnaseq/is...
# 9   https://api.github.com/repos/nf-core/rnaseq/is...
# 10  https://api.github.com/repos/nf-core/rnaseq/is...
# 11  https://api.github.com/repos/nf-core/rnaseq/is...
# 12  https://api.github.com/repos/nf-core/rnaseq/is...
# 13  https://api.github.com/repos/nf-core/rnaseq/is...
# 14  https://api.github.com/repos/nf-core/rnaseq/is...
# 15  https://api.github.com/repos/nf-core/rnaseq/is...
# 16  https://api.github.com/repos/nf-core/rnaseq/is...
# 17  https://api.github.com/repos/nf-core/rnaseq/is...
# 18  https://api.github.com/repos/nf-core/rnaseq/is...
# 19  https://api.github.com/repos/nf-core/rnaseq/is...
# 20  https://api.github.com/repos/nf-core/rnaseq/is...
# 21  https://api.github.com/repos/nf-core/rnaseq/is...
# 22  https://api.github.com/repos/nf-core/rnaseq/is...
# 23  https://api.github.com/repos/nf-core/rnaseq/is...
# 24  https://api.github.com/repos/nf-core/rnaseq/is...
# 25  https://api.github.com/repos/nf-core/rnaseq/is...
# 26  https://api.github.com/repos/nf-core/rnaseq/is...
# 27  https://api.github.com/repos/nf-core/rnaseq/is...
# 28  https://api.github.com/repos/nf-core/rnaseq/is...
# 29  https://api.github.com/repos/nf-core/rnaseq/is...
#
#    performed_via_github_app  state_reason  draft  \
# 0                      None          None    NaN
# 1                      None          None    NaN
# 2                      None          None    NaN
# 3                      None          None    NaN
# 4                      None          None    NaN
# 5                      None          None    NaN
# 6                      None          None    NaN
# 7                      None          None    NaN
# 8                      None          None    NaN
# 9                      None          None    NaN
# 10                     None          None    NaN
# 11                     None          None    NaN
# 12                     None          None    NaN
# 13                     None          None    NaN
# 14                     None          None    NaN
# 15                     None          None    NaN
# 16                     None          None    NaN
# 17                     None          None    NaN
# 18                     None          None   True
# 19                     None          None   True
# 20                     None          None    NaN
# 21                     None          None    NaN
# 22                     None          None    NaN
# 23                     None          None    NaN
# 24                     None          None  False
# 25                     None          None    NaN
# 26                     None      reopened    NaN
# 27                     None          None    NaN
# 28                     None          None  False
# 29                     None          None    NaN
#
#                                          pull_request
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  {'url': 'https://api.github.com/repos/nf-core/...
# 19  {'url': 'https://api.github.com/repos/nf-core/...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  {'url': 'https://api.github.com/repos/nf-core/...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/nf-core/...
# 29                                                NaN
#
# [30 rows x 32 columns]
#                                                   url          id  \
# 0   https://api.github.com/repos/nf-core/rnaseq/pu...  2142194809
# 1   https://api.github.com/repos/nf-core/rnaseq/pu...  2141787507
# 2   https://api.github.com/repos/nf-core/rnaseq/pu...  2132266396
# 3   https://api.github.com/repos/nf-core/rnaseq/pu...  2103715442
# 4   https://api.github.com/repos/nf-core/rnaseq/pu...  1848005982
# 5   https://api.github.com/repos/nf-core/rnaseq/pu...  1748634372
# 6   https://api.github.com/repos/nf-core/rnaseq/pu...  1713974338
# 7   https://api.github.com/repos/nf-core/rnaseq/pu...  1603373291
# 8   https://api.github.com/repos/nf-core/rnaseq/pu...  1594784703
# 9   https://api.github.com/repos/nf-core/rnaseq/pu...  1523641473
# 10  https://api.github.com/repos/nf-core/rnaseq/pu...  1297966803
#
#                 node_id                                     html_url  \
# 0   PR_kwDOB5ZWo85_r0x5  https://github.com/nf-core/rnaseq/pull/1439
# 1   PR_kwDOB5ZWo85_qRVz  https://github.com/nf-core/rnaseq/pull/1438
# 2   PR_kwDOB5ZWo85_F82c  https://github.com/nf-core/rnaseq/pull/1421
# 3   PR_kwDOB5ZWo859ZCZy  https://github.com/nf-core/rnaseq/pull/1397
# 4   PR_kwDOB5ZWo85uJlVe  https://github.com/nf-core/rnaseq/pull/1291
# 5   PR_kwDOB5ZWo85oOgsE  https://github.com/nf-core/rnaseq/pull/1227
# 6   PR_kwDOB5ZWo85mKSxC  https://github.com/nf-core/rnaseq/pull/1209
# 7   PR_kwDOB5ZWo85fkYjr  https://github.com/nf-core/rnaseq/pull/1115
# 8   PR_kwDOB5ZWo85fDnu_  https://github.com/nf-core/rnaseq/pull/1109
# 9   PR_kwDOB5ZWo85a0OyB  https://github.com/nf-core/rnaseq/pull/1076
# 10  PR_kwDOB5ZWo85NXWbT   https://github.com/nf-core/rnaseq/pull/993
#
#                                             diff_url  \
# 0   https://github.com/nf-core/rnaseq/pull/1439.diff
# 1   https://github.com/nf-core/rnaseq/pull/1438.diff
# 2   https://github.com/nf-core/rnaseq/pull/1421.diff
# 3   https://github.com/nf-core/rnaseq/pull/1397.diff
# 4   https://github.com/nf-core/rnaseq/pull/1291.diff
# 5   https://github.com/nf-core/rnaseq/pull/1227.diff
# 6   https://github.com/nf-core/rnaseq/pull/1209.diff
# 7   https://github.com/nf-core/rnaseq/pull/1115.diff
# 8   https://github.com/nf-core/rnaseq/pull/1109.diff
# 9   https://github.com/nf-core/rnaseq/pull/1076.diff
# 10   https://github.com/nf-core/rnaseq/pull/993.diff
#
#                                             patch_url  \
# 0   https://github.com/nf-core/rnaseq/pull/1439.patch
# 1   https://github.com/nf-core/rnaseq/pull/1438.patch
# 2   https://github.com/nf-core/rnaseq/pull/1421.patch
# 3   https://github.com/nf-core/rnaseq/pull/1397.patch
# 4   https://github.com/nf-core/rnaseq/pull/1291.patch
# 5   https://github.com/nf-core/rnaseq/pull/1227.patch
# 6   https://github.com/nf-core/rnaseq/pull/1209.patch
# 7   https://github.com/nf-core/rnaseq/pull/1115.patch
# 8   https://github.com/nf-core/rnaseq/pull/1109.patch
# 9   https://github.com/nf-core/rnaseq/pull/1076.patch
# 10   https://github.com/nf-core/rnaseq/pull/993.patch
#
#                                             issue_url  number state  locked  \
# 0   https://api.github.com/repos/nf-core/rnaseq/is...    1439  open   False
# 1   https://api.github.com/repos/nf-core/rnaseq/is...    1438  open   False
# 2   https://api.github.com/repos/nf-core/rnaseq/is...    1421  open   False
# 3   https://api.github.com/repos/nf-core/rnaseq/is...    1397  open   False
# 4   https://api.github.com/repos/nf-core/rnaseq/is...    1291  open   False
# 5   https://api.github.com/repos/nf-core/rnaseq/is...    1227  open   False
# 6   https://api.github.com/repos/nf-core/rnaseq/is...    1209  open   False
# 7   https://api.github.com/repos/nf-core/rnaseq/is...    1115  open   False
# 8   https://api.github.com/repos/nf-core/rnaseq/is...    1109  open   False
# 9   https://api.github.com/repos/nf-core/rnaseq/is...    1076  open   False
# 10  https://api.github.com/repos/nf-core/rnaseq/is...     993  open   False
#
#     ...                                review_comments_url  \
# 0   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 1   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 2   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 3   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 4   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 5   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 6   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 7   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 8   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 9   ...  https://api.github.com/repos/nf-core/rnaseq/pu...
# 10  ...  https://api.github.com/repos/nf-core/rnaseq/pu...
#
#                                    review_comment_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/pu...
# 1   https://api.github.com/repos/nf-core/rnaseq/pu...
# 2   https://api.github.com/repos/nf-core/rnaseq/pu...
# 3   https://api.github.com/repos/nf-core/rnaseq/pu...
# 4   https://api.github.com/repos/nf-core/rnaseq/pu...
# 5   https://api.github.com/repos/nf-core/rnaseq/pu...
# 6   https://api.github.com/repos/nf-core/rnaseq/pu...
# 7   https://api.github.com/repos/nf-core/rnaseq/pu...
# 8   https://api.github.com/repos/nf-core/rnaseq/pu...
# 9   https://api.github.com/repos/nf-core/rnaseq/pu...
# 10  https://api.github.com/repos/nf-core/rnaseq/pu...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/is...
# 1   https://api.github.com/repos/nf-core/rnaseq/is...
# 2   https://api.github.com/repos/nf-core/rnaseq/is...
# 3   https://api.github.com/repos/nf-core/rnaseq/is...
# 4   https://api.github.com/repos/nf-core/rnaseq/is...
# 5   https://api.github.com/repos/nf-core/rnaseq/is...
# 6   https://api.github.com/repos/nf-core/rnaseq/is...
# 7   https://api.github.com/repos/nf-core/rnaseq/is...
# 8   https://api.github.com/repos/nf-core/rnaseq/is...
# 9   https://api.github.com/repos/nf-core/rnaseq/is...
# 10  https://api.github.com/repos/nf-core/rnaseq/is...
#
#                                          statuses_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/st...
# 1   https://api.github.com/repos/nf-core/rnaseq/st...
# 2   https://api.github.com/repos/nf-core/rnaseq/st...
# 3   https://api.github.com/repos/nf-core/rnaseq/st...
# 4   https://api.github.com/repos/nf-core/rnaseq/st...
# 5   https://api.github.com/repos/nf-core/rnaseq/st...
# 6   https://api.github.com/repos/nf-core/rnaseq/st...
# 7   https://api.github.com/repos/nf-core/rnaseq/st...
# 8   https://api.github.com/repos/nf-core/rnaseq/st...
# 9   https://api.github.com/repos/nf-core/rnaseq/st...
# 10  https://api.github.com/repos/nf-core/rnaseq/st...
#
#                                                  head  \
# 0   {'label': 'nf-core:try_sc_download_fix', 'ref'...
# 1   {'label': 'maxulysse:shard_CI', 'ref': 'shard_...
# 2   {'label': 'idot:allow_int_samplenames', 'ref':...
# 3   {'label': 'rraadd88:patch-1', 'ref': 'patch-1'...
# 4   {'label': 'maxulysse:profile_wave', 'ref': 'pr...
# 5   {'label': 'bentsherman:workflow-inputs-outputs...
# 6   {'label': 'nf-core:optimized-resources', 'ref'...
# 7   {'label': 'bentsherman:cmd-output', 'ref': 'cm...
# 8   {'label': 'bentsherman:topic-channel', 'ref': ...
# 9   {'label': 'maxulysse:uncompress_and_prepare_ge...
# 10  {'label': 'SPPearce:ngscheckmate', 'ref': 'ngs...
#
#                                                  base  \
# 0   {'label': 'nf-core:master', 'ref': 'master', '...
# 1   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 2   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 3   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 4   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 5   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 6   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 7   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 8   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 9   {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
# 10  {'label': 'nf-core:dev', 'ref': 'dev', 'sha': ...
#
#                                                _links author_association  \
# 0   {'self': {'href': 'https://api.github.com/repo...             MEMBER
# 1   {'self': {'href': 'https://api.github.com/repo...             MEMBER
# 2   {'self': {'href': 'https://api.github.com/repo...               NONE
# 3   {'self': {'href': 'https://api.github.com/repo...               NONE
# 4   {'self': {'href': 'https://api.github.com/repo...             MEMBER
# 5   {'self': {'href': 'https://api.github.com/repo...               NONE
# ...
# 29  https://api.github.com/repos/nf-core/rnaseq/ac...
#
#                                       check_suite_url  \
# 0   https://api.github.com/repos/nf-core/rnaseq/ch...
# 1   https://api.github.com/repos/nf-core/rnaseq/ch...
# 2   https://api.github.com/repos/nf-core/rnaseq/ch...
# 3   https://api.github.com/repos/nf-core/rnaseq/ch...
# 4   https://api.github.com/repos/nf-core/rnaseq/ch...
# 5   https://api.github.com/repos/nf-core/rnaseq/ch...
# 6   https://api.github.com/repos/nf-core/rnaseq/ch...
# 7   https://api.github.com/repos/nf-core/rnaseq/ch...
# 8   https://api.github.com/repos/nf-core/rnaseq/ch...
# 9   https://api.github.com/repos/nf-core/rnaseq/ch...
# 10  https://api.github.com/repos/nf-core/rnaseq/ch...
# 11  https://api.github.com/repos/nf-core/rnaseq/ch...
# 12  https://api.github.com/repos/nf-core/rnaseq/ch...
# 13  https://api.github.com/repos/nf-core/rnaseq/ch...
# 14  https://api.github.com/repos/nf-core/rnaseq/ch...
# 15  https://api.github.com/repos/nf-core/rnaseq/ch...
# 16  https://api.github.com/repos/nf-core/rnaseq/ch...
# 17  https://api.github.com/repos/nf-core/rnaseq/ch...
# 18  https://api.github.com/repos/nf-core/rnaseq/ch...
# 19  https://api.github.com/repos/nf-core/rnaseq/ch...
# 20  https://api.github.com/repos/nf-core/rnaseq/ch...
# 21  https://api.github.com/repos/nf-core/rnaseq/ch...
# 22  https://api.github.com/repos/nf-core/rnaseq/ch...
# 23  https://api.github.com/repos/nf-core/rnaseq/ch...
# 24  https://api.github.com/repos/nf-core/rnaseq/ch...
# 25  https://api.github.com/repos/nf-core/rnaseq/ch...
# 26  https://api.github.com/repos/nf-core/rnaseq/ch...
# 27  https://api.github.com/repos/nf-core/rnaseq/ch...
# 28  https://api.github.com/repos/nf-core/rnaseq/ch...
'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 3   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 4   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 5   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 6   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 7   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 8   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 9   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 10  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 11  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 12  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 13  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 14  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 15  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 16  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 17  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 18  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 19  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 20  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 21  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 22  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 23  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 24  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 25  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 26  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 27  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 28  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 29  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
#
#                                       head_repository
# 0   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 1   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 2   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 3   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 4   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 5   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 6   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 7   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 8   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 9   {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 10  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 11  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 12  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 13  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 14  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 15  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 16  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 17  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 18  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 19  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 20  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 21  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 22  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 23  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 24  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 25  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 26  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 27  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 28  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
# 29  {'id': 127293091, 'node_id': 'MDEwOlJlcG9zaXRv...
#
# [30 rows x 35 columns]

# %%
# Extract first and last commits
def get_commit_timeline(repo):
    first_commit = list(repo.iter_commits())[-1]
    last_commit = list(repo.iter_commits())[0]
    print(f"First Commit: {first_commit.authored_datetime}, Author: {first_commit.author.name}")
    print(f"Last Commit: {last_commit.authored_datetime}, Author: {last_commit.author.name}")
    return first_commit, last_commit

first_commit, last_commit = get_commit_timeline(repo)

# Extract contributor activity
def get_contributor_activity(repo):
    contributor_data = {}
    for commit in repo.iter_commits():
        author = commit.author.name
        if author not in contributor_data:
            contributor_data[author] = {
                "First Commit": commit.authored_datetime,
                "Last Commit": commit.authored_datetime,
                "Total Commits": 1
            }
        else:
            contributor_data[author]["Last Commit"] = commit.authored_datetime
            contributor_data[author]["Total Commits"] += 1
    df_contributors = pd.DataFrame.from_dict(contributor_data, orient='index')
    df_contributors["First Commit"] = pd.to_datetime(df_contributors["First Commit"], utc=True).dt.tz_convert(None)
    df_contributors["Last Commit"] = pd.to_datetime(df_contributors["Last Commit"], utc=True).dt.tz_convert(None)
    df_contributors.sort_values(by="Total Commits", ascending=False, inplace=True)
    display(df_contributors)
    return df_contributors

df_contributors = get_contributor_activity(repo)

# Plot contributor activity timeline
def plot_contributor_timeline(df_contributors):
    plt.figure(figsize=(12,6))
    df_contributors.sort_values("First Commit", inplace=True)
    plt.barh(df_contributors.index, (df_contributors["Last Commit"] - df_contributors["First Commit"]).dt.days, color='red')
    plt.xlabel("Days Active")
    plt.ylabel("Contributor")
    plt.title("Contributor Timeline")
    plt.show()

plot_contributor_timeline(df_contributors)

# Findings summary
def summarize_findings(df_contributors, first_commit, last_commit):
    print(f"Total Contributors: {len(df_contributors)}")
    print(f"First Commit Date: {first_commit.authored_datetime}")
    print(f"Last Commit Date: {last_commit.authored_datetime}")
    print("Top Contributors:")
    print(df_contributors.head(10))

summarize_findings(df_contributors, first_commit, last_commit)
# Out:
# First Commit: 2016-03-01 15:40:50+01:00, Author: Phil Ewels
# Last Commit: 2024-12-20 16:49:29+00:00, Author: Jonathan Manning
#                             First Commit         Last Commit  Total Commits
# drpatelh             2021-04-29 11:51:09 2019-06-10 11:42:21           1207
# Harshil Patel        2024-10-23 10:37:19 2019-04-29 14:46:58            963
# Jonathan Manning     2024-12-20 16:49:29 2023-08-08 13:47:24            710
# Phil Ewels           2024-09-06 15:17:04 2016-03-01 14:40:50            635
# Alexander Peltzer    2020-08-17 17:49:19 2017-12-19 10:26:38            364
# ...                                  ...                 ...            ...
# Abhinav Sharma       2020-04-17 11:45:29 2020-04-17 11:45:29              1
# Michael VanInsberghe 2020-03-21 20:17:54 2020-03-21 20:17:54              1
# Peltzer              2020-03-05 09:49:07 2020-03-05 09:49:07              1
# runner               2020-02-20 15:33:25 2020-02-20 15:33:25              1
# Chuan Wang           2016-09-15 13:35:29 2016-09-15 13:35:29              1
#
# [115 rows x 3 columns]
# Total Contributors: 115
# First Commit Date: 2016-03-01 15:40:50+01:00
# Last Commit Date: 2024-12-20 16:49:29+00:00
# Top Contributors:
#                                    First Commit         Last Commit  \
# Chuan Wang                  2016-09-15 13:35:29 2016-09-15 13:35:29
# Denis Moreno                2016-12-09 16:16:29 2016-11-07 16:10:58
# Francesco                   2017-04-19 12:31:27 2017-04-19 12:31:27
# Max Natthawut Adulyanukosol 2017-10-30 15:03:59 2017-10-30 15:03:59
# Colin Davenport             2017-12-14 16:45:55 2017-12-14 16:45:35
# Hammarn                     2018-03-20 08:44:30 2016-07-14 11:39:52
# Rickard Hammarén            2018-03-20 11:46:49 2016-03-07 07:37:30
# Rad Suchecki                2018-04-10 01:32:41 2018-04-10 01:32:41
# Marc                        2018-04-13 14:09:39 2018-04-13 13:34:00
# Lavanya VEERAVALLI          2018-05-30 14:31:21 2018-05-30 07:58:19
#
#                              Total Commits
# Chuan Wang                               1
# Denis Moreno                            54
# Francesco                                1
# Max Natthawut Adulyanukosol              1
# Colin Davenport                          2
# Hammarn                                108
# Rickard Hammarén                       185
# Rad Suchecki                             1
# Marc                                     4
# Lavanya VEERAVALLI                       2

# %%
# Plot timeline chart of commits for each contributor
def plot_commit_timeline(repo):
    commit_data = []
    for commit in repo.iter_commits():
        commit_data.append({
            "Author": commit.author.name,
            "Date": commit.authored_datetime
        })
    df_commits = pd.DataFrame(commit_data)
    df_commits["Date"] = pd.to_datetime(df_commits["Date"], utc=True).dt.tz_convert(None)
    
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=df_commits, x="Date", y="Author", alpha=0.5)
    plt.xticks(rotation=45)
    plt.title("Commit Timeline by Contributor")
    plt.xlabel("Date")
    plt.ylabel("Contributor")
    plt.show()

plot_commit_timeline(repo)

# %%
def plot_commit_heatmap(df_commits):
    df_commits["Date"] = pd.to_datetime(df_commits["Date"], errors="coerce", utc=True).dt.tz_convert(None)
    df_commits["Month"] = df_commits["Date"].dt.to_period("M")
    df_heatmap = df_commits.groupby(["Month", "Author"]).size().unstack(fill_value=0)
    plt.figure(figsize=(12, 8))
    sns.heatmap(df_heatmap, cmap="Greens", linewidths=0.5)
    plt.xticks(rotation=45)
    plt.title("Commit Activity Heatmap (Contributor vs. Time)")
    plt.xlabel("Contributor")
    plt.ylabel("Month")
    plt.show()

plot_commit_heatmap(df_commits)
